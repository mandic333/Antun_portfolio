# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# Principal Component Analysis is an extremely useful linear dimensionality reduction technique.
# It is a very powerful unsupervised method for *dimensionality reduction* in data.
# Useful to explore data, visualize data and relationships.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn
import pylab as pl

from sklearn import neighbors, datasets
from sklearn.decomposition import PCA

seaborn.set()

# %% [markdown]
# Let's import the iris dataset and fit the data:

# %%
iris = datasets.load_iris()

X, y = iris.data, iris.target

pca = PCA(n_components=2)
pca.fit(X)

X_reduced = pca.transform(X)
print("Reduced dataset shape:", X_reduced.shape)

pl.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y,
           cmap='RdYlBu')

print("Meaning of the 2 components:")

for component in pca.components_:
    print(" + ".join("%.3f x %s" % (value, name)
                     for value, name in zip(component,
                                            iris.feature_names)))
# Out:
# Reduced dataset shape: (150, 2)
# Meaning of the 2 components:
# 0.361 x sepal length (cm) + -0.085 x sepal width (cm) + 0.857 x petal length (cm) + 0.358 x petal width (cm)
# 0.657 x sepal length (cm) + 0.730 x sepal width (cm) + -0.173 x petal length (cm) + -0.075 x petal width (cm)

# %% [markdown]
# ## Dimensionality Reduction:

# %%
np.random.seed(1)
X = np.dot(np.random.random(size=(2, 2)), np.random.normal(size=(2, 200))).T

plt.plot(X[:, 0], X[:, 1], 'o')
plt.axis('equal');

# %% [markdown]
# We can see that there is a definite trend in the data.
#
# What PCA seeks to do is to find the **Principal Axes** in the data, and explain how important those axes are in describing the data distribution:

# %%
pca = PCA(n_components=2)
pca.fit(X)

print(pca.explained_variance_)
print(pca.components_)
# Out:
# [0.7625315 0.0184779]
# [[-0.94446029 -0.32862557]
#  [-0.32862557  0.94446029]]

# %%
plt.plot(X[:, 0], X[:, 1], 'o', alpha=0.5)

for length, vector in zip(pca.explained_variance_ratio_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    plt.plot([0, v[0]], [0, v[1]], '-k', lw=3)

plt.axis('equal');

# %% [markdown]
# Now, let's see what our data look like if we only keep 95% of the variance:

# %%
clf = PCA(0.95) # keep 95% of variance
X_trans = clf.fit_transform(X)

print(X.shape)
print(X_trans.shape)
# Out:
# (200, 2)
# (200, 1)

# %% [markdown]
# Isomap: manifold learning, good when PCA doesn't work like in a loop. Large number of datasets, can use randomized PCA.
#
# By specifying that we want to throw away 5% of the variance, the data is now compressed by a factor of 50%!
#
# Let's see what the data look like after this compression:

# %%
X_new = clf.inverse_transform(X_trans)

plt.plot(X[:, 0], X[:, 1], 'o', alpha=0.2)
plt.plot(X_new[:, 0], X_new[:, 1], 'ob', alpha=0.8)
plt.axis('equal');

# %% [markdown]
# The light points are the original data, while the dark points are the projected version.
#
# We see that after truncating 5% of the variance of this dataset and then reprojecting it, the "most important" features of the data are maintained, and we've compressed the data by 50%!
