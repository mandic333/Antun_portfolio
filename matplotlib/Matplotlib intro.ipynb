# %% [markdown]
# # Introduction to matplotlib

# %%
# %matplotlib inline #Statical plots

import pandas as pd
import numpy as np
import pylab as plt
import seaborn

# %%
plt.rc('figure', figsize=(10,5)) #Setting global parameters

seaborn.set()

# %%
x = np.linspace(0, 2, 10)

plt.plot(x, x, 'o-', label='linear')
plt.plot(x, x ** 2, 'x-', label='quadratic')

plt.legend(loc='best')
plt.title('Linear vs Quadratic progression')
plt.xlabel('Input')
plt.ylabel('Output');
plt.show()

# %% [markdown]
# ## Histograms

# %%
samples = np.random.normal(loc=1.0, scale=0.5, size=1000)

print(samples.shape)
print(samples.dtype)
print(samples[:30])

plt.hist(samples, bins=50);
plt.show()
# Out:
# (1000,)
# float64
# [ 1.42003464  1.93697445  1.60228358  1.17059351  0.14793369  0.63243454
#   2.09615968  1.91830611  1.75883994  0.85125764  0.63565306  1.37126781
#   1.36117388  1.42862243  1.77619453  1.36811953  0.47434641 -0.47216787
#   0.71921452  0.03163915  1.35290665  0.58342903  0.55227712  1.43794799
#   1.7050264   0.20013653  1.14175226  1.27288982  0.35230629  1.26449736]

# %% [markdown]
# ## Two histograms on the same plot

# %%
samples_1 = np.random.normal(loc=1, scale=.5, size=10000)
samples_2 = np.random.standard_t(df=10, size=10000)

bins = np.linspace(-3, 3, 50)

plt.hist(samples_1, bins=bins, alpha=0.5, label='samples 1')
plt.hist(samples_2, bins=bins, alpha=0.5, label='samples 2')

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Scattered plots

# %%
plt.scatter(samples_1, samples_2, alpha=0.1)
plt.show()
